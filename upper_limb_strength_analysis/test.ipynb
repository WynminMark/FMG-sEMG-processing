# %%
import pandas as pd
import itertools

# %%
params = {
    'C': [0.1, 1, 10],
    'epsilon': [0.1, 0.2, 0.5],
    'gamma': [0.01, 0.1, 1]
}
a = form_params_grid(params)
a
# Out:
#        C  epsilon  gamma
# 0    0.1      0.1   0.01
# 1    0.1      0.1   0.10
# 2    0.1      0.1   1.00
# 3    0.1      0.2   0.01
# 4    0.1      0.2   0.10
# 5    0.1      0.2   1.00
# 6    0.1      0.5   0.01
# 7    0.1      0.5   0.10
# 8    0.1      0.5   1.00
# 9    1.0      0.1   0.01
# 10   1.0      0.1   0.10
# 11   1.0      0.1   1.00
# 12   1.0      0.2   0.01
# 13   1.0      0.2   0.10
# 14   1.0      0.2   1.00
# 15   1.0      0.5   0.01
# 16   1.0      0.5   0.10
# 17   1.0      0.5   1.00
# 18  10.0      0.1   0.01
# 19  10.0      0.1   0.10
# 20  10.0      0.1   1.00
# 21  10.0      0.2   0.01
# 22  10.0      0.2   0.10
# 23  10.0      0.2   1.00
# 24  10.0      0.5   0.01
# 25  10.0      0.5   0.10
# 26  10.0      0.5   1.00
