# %%
import pandas as pd

from utils_iFEMG_feature import df_save_csv, df_merge_colname

# %%
df1 = pd.read_csv(r"E:\Code_R\healthy_subjects_US_stat\US_tricps_mean_202403.csv", header = [0], index_col = None)
df2 = pd.read_csv(r"E:\Code_R\healthy_subjects_US_stat\US_tricps_mean.csv", header = [0], index_col = 0)

# %%
df1
# Out:
#    subject  weight  bicps_br_R  bicps_br_thickness  tricps_med_R  \
# 0      zjz     0.0   15.271495           33.676667     20.289057
# 1      zjz     0.5   15.589479           33.623333     17.418899
# 2      zjz     1.0   14.249431           35.368333     15.959884
# 3      zjz     2.0         NaN                 NaN           NaN
# 4      lmt     0.0   12.670007           35.400000     12.930559
# 5      lmt     0.5   12.223571           37.168333     12.172346
# 6      lmt     1.0   11.880825           38.360000     11.146756
# 7      lmt     2.0         NaN                 NaN           NaN
# 8      wcx     0.0   19.205531           25.113333     19.033735
# 9      wcx     0.5   18.672136           25.591667     18.691850
# 10     wcx     1.0   17.709528           28.335000     16.228259
# 11     wcx     2.0         NaN                 NaN           NaN
# 12     lmh     0.0   14.270408           38.430000     16.344193
# ...

# %%
df = pd.concat([df1, df2], axis=0, ignore_index=True)
df
# Out:
#    subject  weight  bicps_br_R  bicps_br_thickness  tricps_med_R  \
# 0      zjz     0.0   15.271495           33.676667     20.289057
# 1      zjz     0.5   15.589479           33.623333     17.418899
# 2      zjz     1.0   14.249431           35.368333     15.959884
# 3      zjz     2.0         NaN                 NaN           NaN
# 4      lmt     0.0   12.670007           35.400000     12.930559
# ..     ...     ...         ...                 ...           ...
# 59     lpy     2.0         NaN                 NaN           NaN
# 60     zpk     0.0   12.015171           32.185833     13.118727
# 61     zpk     0.5   11.984691           32.514167     11.363990
# 62     zpk     1.0   11.481628           33.183333     10.837319
# 63     zpk     2.0         NaN                 NaN           NaN
#
#     tricps_med_thickness  tricps_lat_R  tricps_lat_thickness
# 0              45.386667     13.497606             27.206667
# 1              45.020000     14.512295             27.001667
# ...

# %%
df_save_csv(df, r"E:\Code_R\healthy_subjects_US_stat\US_data_202403\US_tricps_mean_2404all.csv")
# Out:
# File E:\Code_R\healthy_subjects_US_stat\US_data_202403\US_tricps_mean_2404all.csv saved!
