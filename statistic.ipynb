# %%
"""
相关性系数计算和显著性检验
"""

import pandas as pd
import numpy as np
import scipy.stats

# %%
data_df = pd.read_csv(r"D:\code\data\iFEMG_data_set\Three_channel_dataset\LiRuya\Lry_bicps_br.csv", header=[0, 1], index_col=0)
data_df.head
# Out:
# <bound method NDFrame.head of     agonist_ch1                                                            \
#    subject_name height(cm) weight(kg) gender age sensor_channel label(kg)
# 0       Li Ruya        165         50      0  34       bicps_br       0.0
# 1       Li Ruya        165         50      0  34       bicps_br       0.0
# 2       Li Ruya        165         50      0  34       bicps_br       0.0
# 3       Li Ruya        165         50      0  34       bicps_br       0.0
# 4       Li Ruya        165         50      0  34       bicps_br       0.0
# 5       Li Ruya        165         50      0  34       bicps_br       0.0
# 6       Li Ruya        165         50      0  34       bicps_br       0.0
# 7       Li Ruya        165         50      0  34       bicps_br       0.0
# 8       Li Ruya        165         50      0  34       bicps_br       0.0
# 9       Li Ruya        165         50      0  34       bicps_br       0.0
# 10      Li Ruya        165         50      0  34       bicps_br       0.5
# 11      Li Ruya        165         50      0  34       bicps_br       0.5
# 12      Li Ruya        165         50      0  34       bicps_br       0.5
# 13      Li Ruya        165         50      0  34       bicps_br       0.5
# 14      Li Ruya        165         50      0  34       bicps_br       0.5
# 15      Li Ruya        165         50      0  34       bicps_br       0.5
# 16      Li Ruya        165         50      0  34       bicps_br       0.5
# 17      Li Ruya        165         50      0  34       bicps_br       0.5
# 18      Li Ruya        165         50      0  34       bicps_br       0.5
# 19      Li Ruya        165         50      0  34       bicps_br       0.5
# 20      Li Ruya        165         50      0  34       bicps_br       1.0
# 21      Li Ruya        165         50      0  34       bicps_br       1.0
# 22      Li Ruya        165         50      0  34       bicps_br       1.0
# 23      Li Ruya        165         50      0  34       bicps_br       1.0
# 24      Li Ruya        165         50      0  34       bicps_br       1.0
# 25      Li Ruya        165         50      0  34       bicps_br       1.0
# 26      Li Ruya        165         50      0  34       bicps_br       1.0
# 27      Li Ruya        165         50      0  34       bicps_br       1.0
# 28      Li Ruya        165         50      0  34       bicps_br       1.0
# 29      Li Ruya        165         50      0  34       bicps_br       1.0
# 30      Li Ruya        165         50      0  34       bicps_br       1.0
# 31      Li Ruya        165         50      0  34       bicps_br       2.0
# 32      Li Ruya        165         50      0  34       bicps_br       2.0
# 33      Li Ruya        165         50      0  34       bicps_br       2.0
# 34      Li Ruya        165         50      0  34       bicps_br       2.0
# 35      Li Ruya        165         50      0  34       bicps_br       2.0
# 36      Li Ruya        165         50      0  34       bicps_br       2.0
# 37      Li Ruya        165         50      0  34       bicps_br       2.0
# 38      Li Ruya        165         50      0  34       bicps_br       2.0
# 39      Li Ruya        165         50      0  34       bicps_br       2.0
# 40      Li Ruya        165         50      0  34       bicps_br       2.0
#
#                                      ...     antagonist_ch2            \
#    FMG_increase       mav       rms  ...     sensor_channel label(kg)
# 0      0.471172  2.514380  2.086666  ...  tricps_br_lateral       0.0
# 1      0.517664  2.187099  1.613529  ...  tricps_br_lateral       0.0
# 2      0.435896  2.003939  1.401478  ...  tricps_br_lateral       0.0
# 3      0.534742  2.665446  2.287314  ...  tricps_br_lateral       0.0
# 4      0.557122  2.367349  1.814453  ...  tricps_br_lateral       0.0
# 5      0.427768  2.152498  1.771144  ...  tricps_br_lateral       0.0
# 6      0.486281  2.873244  2.436851  ...  tricps_br_lateral       0.0
# 7      0.497752  2.161924  1.771313  ...  tricps_br_lateral       0.0
# 8      0.402966  1.992843  1.790840  ...  tricps_br_lateral       0.0
# 9      0.428800  1.766193  1.527928  ...  tricps_br_lateral       0.0
# 10     0.670838  4.081780  2.947068  ...  tricps_br_lateral       0.5
# 11     0.504816  2.824126  2.148122  ...  tricps_br_lateral       0.5
# 12     0.482234  1.473401  0.616683  ...  tricps_br_lateral       0.5
# 13     0.433963  1.259570  0.448604  ...  tricps_br_lateral       0.5
# 14     0.417843  0.967292  0.333765  ...  tricps_br_lateral       0.5
# 15     0.453326  2.912476  1.707723  ...  tricps_br_lateral       0.5
# 16     0.420584  2.156663  1.481314  ...  tricps_br_lateral       0.5
# 17     0.401651  1.555772  0.802102  ...  tricps_br_lateral       0.5
# 18     0.371290  1.497826  1.093113  ...  tricps_br_lateral       0.5
# 19     0.461756  2.824327  1.768080  ...  tricps_br_lateral       0.5
# 20     0.717874  6.540241  6.441601  ...  tricps_br_lateral       1.0
# 21     0.474852  2.168538  1.317507  ...  tricps_br_lateral       1.0
# 22     0.382118  1.976203  1.420336  ...  tricps_br_lateral       1.0
# 23     0.416812  2.006047  0.812956  ...  tricps_br_lateral       1.0
# 24     0.454529  1.764811  1.011924  ...  tricps_br_lateral       1.0
# 25     0.395374  1.369627  0.710333  ...  tricps_br_lateral       1.0
# 26     0.325866  0.926586  0.716909  ...  tricps_br_lateral       1.0
# 27     0.292595  1.133861  0.793312  ...  tricps_br_lateral       1.0
# 28    -0.100886 -0.221726 -0.295683  ...  tricps_br_lateral       1.0
# 29     0.045713 -0.229628 -0.238033  ...  tricps_br_lateral       1.0
# 30     0.381698  0.914066  0.688040  ...  tricps_br_lateral       1.0
# 31     0.820729  5.897520  5.674230  ...  tricps_br_lateral       2.0
# 32     0.355672  1.035549  0.886396  ...  tricps_br_lateral       2.0
# 33     0.382723  1.998903  1.186209  ...  tricps_br_lateral       2.0
# 34     0.321547  1.368138  0.882665  ...  tricps_br_lateral       2.0
# 35     0.288528  1.626359  1.205291  ...  tricps_br_lateral       2.0
# 36     0.320848  1.748293  1.289514  ...  tricps_br_lateral       2.0
# 37     0.215330  1.532296  1.340613  ...  tricps_br_lateral       2.0
# 38     0.283402  1.855481  1.384830  ...  tricps_br_lateral       2.0
# 39     0.343467  2.185439  1.704445  ...  tricps_br_lateral       2.0
# 40     0.243151  1.531976  1.341712  ...  tricps_br_lateral       2.0
# 7          -0.013664  47.829380       77.925240
# 8          -0.011175  49.549103       81.712762
# 9          -0.015468  52.051553       86.486201
# 10         -0.062901  33.939695       46.403381
# 11         -0.030508  48.603603       71.662097
# 12         -0.018691  46.706372       70.111035
# 13         -0.018808  47.486380       73.851682
# 14         -0.054299  48.949492       65.700971
# 15         -0.052248  45.495781       64.360457
# 16         -0.032361  51.595251       77.788917
# 17         -0.040884  51.029063       71.787582
# 18         -0.027442  53.544107       82.335418
# 19         -0.021251  48.473450       72.968694
# 20         -0.054804  40.318172       50.648351
# 21         -0.047798  44.423794       59.549229
# 22         -0.014268  46.066999       65.494308
# 23         -0.044245  45.000632       65.568285
# 24         -0.027325  44.361334       66.770033
# 25         -0.042617  43.796914       66.852711
# 26          0.007348  51.853025       75.714158
# 27         -0.051133  45.630810       67.594177
# 28         -0.023202  35.517199       50.588296
# 29          0.043676  56.439193       93.817270
# 30         -0.044056  39.265752       50.741773
# 31         -0.105241  39.400095       51.512551
# 32         -0.027473  42.645398       56.444589
# 33         -0.070335  48.124113       68.144364
# 34         -0.099372  51.815767       72.081515
# 35         -0.073246  47.190410       65.186688
# 36         -0.069884  49.641048       68.595272
# 37         -0.066994  53.411785       69.507004
# 38         -0.065093  52.267814       74.306342
# 39         -0.069249  46.880415       67.832887
# 40          0.014846  53.068401       69.302155
#
# [41 rows x 45 columns]>

# %%
# 获取要进行相关性分析的数据
data_2test = data_df['antagonist_ch2'][['label(kg)', 'FMG_increase', 'mav', 'rms', 'wave_length', 'zero_crossing', 'slope_sign_change', 'mean_freq', 'mean_power_freq']]
data_2test.head
# Out:
# <bound method NDFrame.head of     label(kg)  FMG_increase       mav       rms  wave_length  zero_crossing  \
# 0         0.0      0.068173  0.396347  0.641543    -0.182088      -0.238937
# 1         0.0      0.093054  0.103456  0.158986    -0.136970      -0.208587
# 2         0.0      0.133377  0.294299  0.416913     0.039544      -0.188784
# 3         0.0      0.118255  0.206188  0.328327    -0.092453      -0.162825
# 4         0.0      0.121881  0.197040  0.257323    -0.043782      -0.115291
# 5         0.0      0.129737  0.401608  0.494001     0.076364      -0.212398
# 6         0.0      0.092484  0.159821  0.197069    -0.073421      -0.214420
# 7         0.0      0.131146  0.396031  0.475918     0.070081      -0.238027
# 8         0.0      0.108812  0.365621  0.497410     0.037570      -0.224544
# 9         0.0      0.105620  0.276826  0.331605     0.034435      -0.199000
# 10        0.5      0.132476  0.808169  1.171819     0.100447      -0.303545
# 11        0.5      0.084574  0.496985  0.627143     0.085969      -0.290833
# 12        0.5      0.091182  0.279926  0.457797     0.116677      -0.082888
# 13        0.5      0.084045  0.522300  0.706331     0.090978      -0.253465
# 14        0.5      0.079361  0.561114  0.745293     0.156770      -0.227849
# 15        0.5      0.075705  0.687585  0.890203     0.148751      -0.254346
# 16        0.5      0.078011  0.549680  0.647671     0.187247      -0.171039
# 30          -0.044056  39.265752        50.741773
# 31          -0.105241  39.400095        51.512551
# 32          -0.027473  42.645398        56.444589
# 33          -0.070335  48.124113        68.144364
# 34          -0.099372  51.815767        72.081515
# 35          -0.073246  47.190410        65.186688
# 36          -0.069884  49.641048        68.595272
# 37          -0.066994  53.411785        69.507004
# 38          -0.065093  52.267814        74.306342
# 39          -0.069249  46.880415        67.832887
# 40           0.014846  53.068401        69.302155  >

# %%
"""
pearson : Standard correlation coefficient
kendall : Kendall Tau correlation coefficient
spearman : Spearman rank correlation
callable: Callable with input two 1d ndarrays and returning a float.
"""
corr_result = data_2test.corr(method="pearson")
corr_result
# Out:
#                    label(kg)  FMG_increase       mav       rms  wave_length  \
# label(kg)           1.000000     -0.200705  0.580247  0.483318     0.915095
# FMG_increase       -0.200705      1.000000  0.238586  0.304385    -0.008836
# mav                 0.580247      0.238586  1.000000  0.983760     0.743917
# rms                 0.483318      0.304385  0.983760  1.000000     0.657927
# wave_length         0.915095     -0.008836  0.743917  0.657927     1.000000
# zero_crossing       0.240191     -0.199802 -0.566301 -0.606683     0.038671
# slope_sign_change  -0.381473     -0.184463 -0.679936 -0.701910    -0.425461
# mean_freq           0.135014     -0.120310 -0.136389 -0.211383     0.175212
# mean_power_freq    -0.236811     -0.072609 -0.410531 -0.461103    -0.213291
#
#                    zero_crossing  slope_sign_change  mean_freq  \
# label(kg)               0.240191          -0.381473   0.135014
# FMG_increase           -0.199802          -0.184463  -0.120310
# mav                    -0.566301          -0.679936  -0.136389
# rms                    -0.606683          -0.701910  -0.211383
# wave_length             0.038671          -0.425461   0.175212
# zero_crossing           1.000000           0.348996   0.221040
# slope_sign_change       0.348996           1.000000   0.451530
# mean_freq               0.221040           0.451530   1.000000
# mean_power_freq         0.184651           0.576017   0.870165
#
#                    mean_power_freq
# label(kg)                -0.236811
# FMG_increase             -0.072609
# mav                      -0.410531
# rms                      -0.461103
# wave_length              -0.213291
# zero_crossing             0.184651
# slope_sign_change         0.576017
# mean_freq                 0.870165
# mean_power_freq           1.000000

# %%
# 皮尔逊相关系数的显著性检验
# 各个相关系数检验的统计量
def r_test_statistic(r, n): 
    """# 构建t分布  
    n:样本容量  
    r:相关系数
    """
    if r == 1:
        return 0
    else:
        a = abs(r)
        b = np.sqrt((n - 2) / (1 - r ** 2))
        c = a * b
        return c
 
# 计算各个相关系数检验的统计量
corr_test_stat = corr_result.applymap(lambda x: r_test_statistic(x, len(data_2test)))
print('--------------------------')
print(corr_test_stat)
 
"""
单样本t检验自由度dt=n-1,
独立t检验自由度dt=n-2
配对t检验自由度dt=n/2-1
"""
# 根据显著性水平0.05和自由度n-2=25-2=23， 计算t分布临界值
alpha = 0.05
t_score = scipy.stats.t.isf(alpha/2, df = len(data_2test)-2)
print('--------------------------')
print("t_score: ", t_score)
# |t| >= t_score, 表明总体两变量线性相关性显著
# Out:
# --------------------------
#                    label(kg)  FMG_increase        mav        rms  wave_length  \
# label(kg)           0.000000      1.279439   4.449235   3.447759    14.172144
# FMG_increase        1.279439      0.000000   1.534278   1.995578     0.055185
# mav                 4.449235      1.534278   0.000000  34.227672     6.951905
# rms                 3.447759      1.995578  34.227672   0.000000     5.455920
# wave_length        14.172144      0.055185   6.951905   5.455920     0.000000
# zero_crossing       1.545226      1.273442   4.290896   4.766044     0.241683
# slope_sign_change   2.577182      1.172086   5.790753   6.154200     2.935990
# mean_freq           0.850954      0.756831   0.859783   1.350606     1.111389
# mean_power_freq     1.522181      0.454645   2.811622   3.245171     1.363376
#
#                    zero_crossing  slope_sign_change  mean_freq  \
# label(kg)               1.545226           2.577182   0.850954
# FMG_increase            1.273442           1.172086   0.756831
# mav                     4.290896           5.790753   0.859783
# rms                     4.766044           6.154200   1.350606
# wave_length             0.241683           2.935990   1.111389
# zero_crossing           0.000000           2.325713   1.415406
# slope_sign_change       2.325713           0.000000   3.160306
# mean_freq               1.415406           3.160306   0.000000
# mean_power_freq         1.173320           4.400606  11.028019
#
#                    mean_power_freq
# label(kg)                 1.522181
# FMG_increase              0.454645
# mav                       2.811622
# rms                       3.245171
# wave_length               1.363376
# zero_crossing             1.173320
# slope_sign_change         4.400606
# mean_freq                11.028019
# mean_power_freq           0.000000
# --------------------------
# t_score:  2.0226909117347285

# %%
data_2test.corr(method="spearman")
# Out:
#                    label(kg)  FMG_increase       mav       rms  wave_length  \
# label(kg)           1.000000     -0.451211  0.650460  0.583174     0.890008
# FMG_increase       -0.451211      1.000000 -0.166028 -0.102439    -0.317944
# mav                 0.650460     -0.166028  1.000000  0.985540     0.795122
# rms                 0.583174     -0.102439  0.985540  1.000000     0.726655
# wave_length         0.890008     -0.317944  0.795122  0.726655     1.000000
# zero_crossing       0.141408     -0.322474 -0.410279 -0.467247     0.046864
# slope_sign_change  -0.451031      0.142334 -0.650697 -0.681359    -0.469686
# mean_freq           0.035712     -0.295122 -0.138153 -0.212195     0.052787
# mean_power_freq    -0.310073      0.000697 -0.382056 -0.432578    -0.256272
#
#                    zero_crossing  slope_sign_change  mean_freq  \
# label(kg)               0.141408          -0.451031   0.035712
# FMG_increase           -0.322474           0.142334  -0.295122
# mav                    -0.410279          -0.650697  -0.138153
# rms                    -0.467247          -0.681359  -0.212195
# wave_length             0.046864          -0.469686   0.052787
# zero_crossing           1.000000           0.251742   0.404878
# slope_sign_change       0.251742           1.000000   0.301568
# mean_freq               0.404878           0.301568   1.000000
# mean_power_freq         0.314634           0.525610   0.847213
#
#                    mean_power_freq
# label(kg)                -0.310073
# FMG_increase              0.000697
# mav                      -0.382056
# rms                      -0.432578
# wave_length              -0.256272
# zero_crossing             0.314634
# slope_sign_change         0.525610
# mean_freq                 0.847213
# mean_power_freq           1.000000

# %%
len(data_2test)
# Out:
# 41
